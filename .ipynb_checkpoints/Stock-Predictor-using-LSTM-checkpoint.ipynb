# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import datetime
import math, time
import itertools
from sklearn import preprocessing
import datetime
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from pandas import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
from matplotlib import pyplot

# %% [markdown]
# * Get the stock data from Yahoo finance as a CSV for any company.
#
# * Drop all other columns (Volume, Year, Month and Day) and retain Open, High and Close - since I'm just predicting the close value for a day

# %%
col_names = ['Timestamp','Sequence','Open','High','Low','Close','Volume']
apple = pd.read_csv('AAPL.csv')
apple.columns = col_names
apple['Timestamp'] =  pd.to_datetime(apple['Timestamp'],format='%Y-%m-%d %H:%M:%S')
apple.index = apple['Timestamp']
apple = apple.drop(['Sequence','Timestamp'],axis =1)
apple.head()
# Out:
#                          Open     High       Low     Close  Volume
# Timestamp
# 2018-03-12 15:49:00  181.5762  181.750  181.5762  181.6900   48721
# 2018-03-12 15:50:00  181.6986  181.710  181.5700  181.5745   51915
# 2018-03-12 15:51:00  181.6600  181.720  181.6400  181.6924   32218
# 2018-03-12 15:52:00  181.5100  181.675  181.5000  181.6700   62321
# 2018-03-12 15:53:00  181.7200  181.720  181.5100  181.5200   34506

# %%
apple = apple[['Close']]

# %% [markdown]
# * Let me save the data to a CSV file so that I can refer later (if needed :) )

# %%
apple.head()
# Out:
#                         Close
# Timestamp
# 2018-03-12 15:49:00  181.6900
# 2018-03-12 15:50:00  181.5745
# 2018-03-12 15:51:00  181.6924
# 2018-03-12 15:52:00  181.6700
# 2018-03-12 15:53:00  181.5200

# %%
df = apple.loc['2018-03-13']

# %%
plt.figure(figsize=(15,8))
plt.plot(df)

# %%
# split data into train and test
X = df.values
train, test = X[0:300], X[300:]

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# make prediction
	predictions.append(history[-1])
	# observation
	history.append(test[i])
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(test)
pyplot.plot(predictions)
pyplot.show()
# Out:
# RMSE: 0.123

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
	df = DataFrame(data)
	columns = [df.shift(i) for i in range(1, lag+1)]
	columns.append(df)
	df = concat(columns, axis=1)
	df.fillna(0, inplace=True)
	return df

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from pandas import concat
 
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
	df = DataFrame(data)
	columns = [df.shift(i) for i in range(1, lag+1)]
	columns.append(df)
	df = concat(columns, axis=1)
	df.fillna(0, inplace=True)
	return df
 

# transform to supervised learning
X = df.values
supervised = timeseries_to_supervised(X, 1)
print(supervised.head())
# Out:
#           0         0
# 0    0.0000  182.5900
# 1  182.5900  182.4975
# 2  182.4975  182.7900
# 3  182.7900  182.6700
# 4  182.6700  182.2300

# %%
from pandas import read_csv
from pandas import datetime
from pandas import Series

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

series = df['Close']

print(series.head())
# transform to be stationary
differenced = difference(series, 1)
print(differenced.head())
# invert transform
inverted = list()
for i in range(len(differenced)):
	value = inverse_difference(series, differenced[i], len(series)-i)
	inverted.append(value)
inverted = Series(inverted)
print(inverted.head())
# Out:
# Timestamp
# 2018-03-13 13:30:00    182.5900
# 2018-03-13 13:31:00    182.4975
# 2018-03-13 13:32:00    182.7900
# 2018-03-13 13:33:00    182.6700
# 2018-03-13 13:34:00    182.2300
# Name: Close, dtype: float64
# 0   -0.0925
# 1    0.2925
# 2   -0.1200
# 3   -0.4400
# 4    0.2200
# dtype: float64
# 0    182.4975
# 1    182.7900
# 2    182.6700
# 3    182.2300
# 4    182.4500
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# transform scale
X = series.values
X = X.reshape(len(X), 1)
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(X)
scaled_X = scaler.transform(X)

# %%
# invert transform
inverted_X = scaler.inverse_transform(scaled_X)

# %%
series = df['Close']
print(series.head())
# transform scale
X = series.values
X = X.reshape(len(X), 1)
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(X)
scaled_X = scaler.transform(X)
scaled_series = Series(scaled_X[:, 0])
print(scaled_series.head())
# invert transform
inverted_X = scaler.inverse_transform(scaled_X)
inverted_series = Series(inverted_X[:, 0])
print(inverted_series.head())
# Out:
# Timestamp
# 2018-03-13 13:30:00    182.5900
# 2018-03-13 13:31:00    182.4975
# 2018-03-13 13:32:00    182.7900
# 2018-03-13 13:33:00    182.6700
# 2018-03-13 13:34:00    182.2300
# Name: Close, dtype: float64
# 0    0.578199
# 1    0.534360
# 2    0.672986
# 3    0.616114
# 4    0.407583
# dtype: float64
# 0    182.5900
# 1    182.4975
# 2    182.7900
# 3    182.6700
# 4    182.2300
# dtype: float64

# %%
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
from matplotlib import pyplot
import numpy

# date-time parsing function for loading the dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
	df = DataFrame(data)
	columns = [df.shift(i) for i in range(1, lag+1)]
	columns.append(df)
	df = concat(columns, axis=1)
	df.fillna(0, inplace=True)
	return df

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# scale train and test data to [-1, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled

# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
	new_row = [x for x in X] + [value]
	array = numpy.array(new_row)
	array = array.reshape(1, len(array))
	inverted = scaler.inverse_transform(array)
	return inverted[0, -1]

# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
	X, y = train[:, 0:-1], train[:, -1]
	X = X.reshape(X.shape[0], 1, X.shape[1])
	model = Sequential()
	model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
	model.add(Dense(1))
	model.compile(loss='mean_squared_error', optimizer='adam')
	for i in range(nb_epoch):
		model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
		model.reset_states()
	return model

# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# load dataset
series = df["Close"]

# transform data to be stationary
raw_values = series.values
diff_values = difference(raw_values, 1)

# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

# split data into train and test-sets
train, test = supervised_values[0:-290], supervised_values[-290:]

# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# fit the model
lstm_model = fit_lstm(train_scaled, 1, 20, 4)
# forecast the entire training dataset to build up state for forecasting
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
lstm_model.predict(train_reshaped, batch_size=1)

# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_lstm(lstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
	# invert differencing
	yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Minute=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))

# report performance
rmse = sqrt(mean_squared_error(raw_values[-290:], predictions))
print('Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.figure(figsize=(15,8))
pyplot.plot(raw_values[-290:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# Epoch 1/1
#  - 4s - loss: 0.0927
# Epoch 1/1
#  - 0s - loss: 0.0879
# Epoch 1/1
#  - 0s - loss: 0.0870
# Epoch 1/1
#  - 0s - loss: 0.0864
# Epoch 1/1
#  - 0s - loss: 0.0859
# Epoch 1/1
#  - 0s - loss: 0.0856
# Epoch 1/1
#  - 0s - loss: 0.0853
# Epoch 1/1
#  - 0s - loss: 0.0851
# Epoch 1/1
#  - 0s - loss: 0.0849
# Epoch 1/1
#  - 0s - loss: 0.0847
# Epoch 1/1
#  - 0s - loss: 0.0846
# Epoch 1/1
#  - 0s - loss: 0.0845
# Epoch 1/1
#  - 0s - loss: 0.0844
# Epoch 1/1
#  - 0s - loss: 0.0843
# Epoch 1/1
#  - 0s - loss: 0.0843
# Epoch 1/1
#  - 0s - loss: 0.0842
# Epoch 1/1
#  - 0s - loss: 0.0841
# Epoch 1/1
#  - 0s - loss: 0.0840
# Epoch 1/1
#  - 0s - loss: 0.0839
# Epoch 1/1
#  - 0s - loss: 0.0839
# Minute=1, Predicted=182.220425, Expected=181.950000
# Minute=2, Predicted=181.979995, Expected=182.190000
# Minute=3, Predicted=182.215896, Expected=182.285000
# Minute=4, Predicted=182.295833, Expected=182.240000
# Minute=5, Predicted=182.236785, Expected=182.210000
# Minute=6, Predicted=182.203545, Expected=182.370000
# Minute=7, Predicted=182.370629, Expected=182.190000
# Minute=8, Predicted=182.179285, Expected=182.130000
# Minute=9, Predicted=182.123574, Expected=182.050000
# Minute=10, Predicted=182.047318, Expected=182.206100
# Minute=11, Predicted=182.209191, Expected=182.380000
# Minute=12, Predicted=182.384107, Expected=182.440000
# Minute=13, Predicted=182.427547, Expected=182.510000
# Minute=14, Predicted=182.492842, Expected=182.440000
# Minute=15, Predicted=182.412306, Expected=182.490000
# Minute=16, Predicted=182.468791, Expected=182.380000
# Minute=17, Predicted=182.357121, Expected=181.961400
# Minute=18, Predicted=181.976257, Expected=182.118000
# Minute=19, Predicted=182.124622, Expected=181.705000
# Minute=20, Predicted=181.741176, Expected=181.810000
# Minute=21, Predicted=181.827624, Expected=181.943800
# Minute=22, Predicted=181.957104, Expected=182.120000
# Minute=23, Predicted=182.131056, Expected=181.950000
# Minute=24, Predicted=181.940946, Expected=181.880000
# Minute=25, Predicted=181.874069, Expected=181.660000
# Minute=26, Predicted=181.668395, Expected=181.390000
# Minute=27, Predicted=181.419472, Expected=181.520000
# Minute=28, Predicted=181.537673, Expected=181.690000
# Minute=29, Predicted=181.706040, Expected=181.710000
# Minute=30, Predicted=181.708883, Expected=181.720000
# Minute=31, Predicted=181.711686, Expected=181.750000
# Minute=32, Predicted=181.738247, Expected=181.800000
# Minute=33, Predicted=181.786134, Expected=181.959900
# Minute=34, Predicted=181.954075, Expected=182.010000
# Minute=35, Predicted=181.990348, Expected=181.985000
# Minute=36, Predicted=181.957609, Expected=181.970000
# Minute=37, Predicted=181.944062, Expected=181.970000
# Minute=38, Predicted=181.946684, Expected=181.909900
# Minute=39, Predicted=181.888489, Expected=182.062000
# Minute=40, Predicted=182.053838, Expected=182.100000
# Minute=41, Predicted=182.082111, Expected=182.140000
# Minute=42, Predicted=182.119918, Expected=182.100000
# Minute=43, Predicted=182.075572, Expected=182.230000
# Minute=44, Predicted=182.217053, Expected=182.210000
# Minute=45, Predicted=182.185685, Expected=182.230000
# Minute=46, Predicted=182.207620, Expected=182.240000
# Minute=47, Predicted=182.217528, Expected=182.170000
# Minute=48, Predicted=182.147815, Expected=182.140000
# Minute=49, Predicted=182.122546, Expected=182.270000
# Minute=50, Predicted=182.261655, Expected=182.210000
# Minute=51, Predicted=182.191769, Expected=181.965000
# Minute=52, Predicted=181.961308, Expected=181.850000
# Minute=53, Predicted=181.853893, Expected=181.840000
# Minute=54, Predicted=181.844454, Expected=181.850000
# Minute=55, Predicted=181.852949, Expected=181.670000
# Minute=56, Predicted=181.680410, Expected=181.350000
# Minute=57, Predicted=181.386500, Expected=181.540000
# Minute=58, Predicted=181.563179, Expected=181.260000
# Minute=59, Predicted=181.293752, Expected=180.870000
# Minute=60, Predicted=180.931698, Expected=180.940000
# Minute=61, Predicted=180.973022, Expected=181.070000
# Minute=62, Predicted=181.094378, Expected=181.300000
# Minute=63, Predicted=181.325226, Expected=181.180000
# Minute=64, Predicted=181.177433, Expected=181.180000
# Minute=65, Predicted=181.175332, Expected=181.210000
# Minute=66, Predicted=181.202134, Expected=181.390000
# Minute=67, Predicted=181.391007, Expected=181.500000
# Minute=68, Predicted=181.490742, Expected=181.560000
# Minute=69, Predicted=181.540540, Expected=181.630000
# Minute=70, Predicted=181.607789, Expected=181.665000
# Minute=71, Predicted=181.637525, Expected=181.770000
# Minute=72, Predicted=181.748548, Expected=181.830000
# Minute=73, Predicted=181.803370, Expected=181.790000
# Minute=74, Predicted=181.756120, Expected=181.840000
# Minute=75, Predicted=181.813418, Expected=181.780000
# Minute=76, Predicted=181.750901, Expected=181.655000
# Minute=77, Predicted=181.633964, Expected=181.529000
# Minute=78, Predicted=181.519512, Expected=181.530000
# Minute=79, Predicted=181.524445, Expected=181.530000
# Minute=80, Predicted=181.525242, Expected=181.720000
# Minute=81, Predicted=181.725507, Expected=181.860000
# Minute=82, Predicted=181.858773, Expected=181.930000
# Minute=83, Predicted=181.915739, Expected=181.990000
# Minute=84, Predicted=181.969652, Expected=182.050000
# Minute=85, Predicted=182.026527, Expected=182.010000
# Minute=86, Predicted=181.978809, Expected=182.035000
# Minute=87, Predicted=182.008808, Expected=181.920000
# Minute=88, Predicted=181.894726, Expected=181.990000
# Minute=89, Predicted=181.973707, Expected=182.020000
# Minute=90, Predicted=182.002418, Expected=182.008900
# Minute=91, Predicted=181.989651, Expected=181.987600
# Minute=92, Predicted=181.969194, Expected=181.910000
# Minute=93, Predicted=181.894421, Expected=181.830000
# Minute=94, Predicted=181.820094, Expected=181.810000
# Minute=95, Predicted=181.803192, Expected=181.650000
# Minute=96, Predicted=181.652039, Expected=181.655000
# Minute=97, Predicted=181.656841, Expected=181.550000
# Minute=98, Predicted=181.555060, Expected=181.809000
# Minute=99, Predicted=181.828372, Expected=182.000000
# Minute=100, Predicted=182.012424, Expected=182.000000
# Minute=101, Predicted=181.985377, Expected=182.040000
# Minute=102, Predicted=182.022024, Expected=182.150000
# Minute=103, Predicted=182.135151, Expected=182.126000
# Minute=104, Predicted=182.098314, Expected=182.149900
# Minute=105, Predicted=182.124810, Expected=182.160000
# Minute=106, Predicted=182.134846, Expected=182.070000
# Minute=107, Predicted=182.045703, Expected=182.100000
# Minute=108, Predicted=182.082187, Expected=182.054400
# Minute=109, Predicted=182.037002, Expected=182.130000
# Minute=110, Predicted=182.117810, Expected=182.078500
# Minute=111, Predicted=182.061837, Expected=182.010000
# Minute=112, Predicted=181.996434, Expected=182.250000
# Minute=113, Predicted=182.257864, Expected=182.335000
# Minute=114, Predicted=182.325740, Expected=182.194900
# Minute=115, Predicted=182.172761, Expected=182.280000
# Minute=116, Predicted=182.266617, Expected=182.359900
# Minute=117, Predicted=182.345085, Expected=182.180000
# Minute=118, Predicted=182.160790, Expected=182.260000
# Minute=119, Predicted=182.248621, Expected=182.220000
# Minute=120, Predicted=182.204746, Expected=182.320000
# Minute=121, Predicted=182.310295, Expected=182.290000
# Minute=122, Predicted=182.272377, Expected=182.310100
# Minute=123, Predicted=182.293732, Expected=182.320000
# Minute=124, Predicted=182.302679, Expected=182.360000
# Minute=125, Predicted=182.343417, Expected=182.379300
# Minute=126, Predicted=182.360775, Expected=182.420000
# Minute=127, Predicted=182.401754, Expected=182.374900
# Minute=128, Predicted=182.353495, Expected=182.430000
# Minute=129, Predicted=182.413327, Expected=182.410000
# Minute=130, Predicted=182.390229, Expected=182.335000
# Minute=131, Predicted=182.317353, Expected=182.400000
# Minute=132, Predicted=182.387688, Expected=182.440000
# Minute=133, Predicted=182.425701, Expected=182.410000
# Minute=134, Predicted=182.392335, Expected=182.280000
# Minute=135, Predicted=182.267057, Expected=182.150000
# Minute=136, Predicted=182.146780, Expected=182.150000
# Minute=137, Predicted=182.148537, Expected=182.176200
# Minute=138, Predicted=182.174073, Expected=182.150000
# Minute=139, Predicted=182.145325, Expected=182.170000
# Minute=140, Predicted=182.164140, Expected=182.130000
# Minute=141, Predicted=182.121784, Expected=182.197600
# Minute=142, Predicted=182.190631, Expected=182.210100
# Minute=143, Predicted=182.198070, Expected=182.099900
# Minute=144, Predicted=182.087724, Expected=182.170000
# Minute=145, Predicted=182.161793, Expected=182.290000
# Minute=146, Predicted=182.283738, Expected=182.220000
# Minute=147, Predicted=182.202018, Expected=182.210000
# Minute=148, Predicted=182.194094, Expected=182.225000
# Minute=149, Predicted=182.209941, Expected=182.300000
# Minute=150, Predicted=182.287097, Expected=182.333800
# Minute=151, Predicted=182.316592, Expected=182.290000
# Minute=152, Predicted=182.269190, Expected=182.310000
# Minute=153, Predicted=182.292175, Expected=182.230000
# Minute=154, Predicted=182.212504, Expected=182.230000
# Minute=155, Predicted=182.216366, Expected=182.220000
# Minute=156, Predicted=182.207231, Expected=182.050000
# Minute=157, Predicted=182.045131, Expected=181.853000
# Minute=158, Predicted=181.863346, Expected=181.930000
# Minute=159, Predicted=181.936817, Expected=181.740000
# Minute=160, Predicted=181.754692, Expected=181.609800
# Minute=161, Predicted=181.628620, Expected=181.680000
# Minute=162, Predicted=181.692768, Expected=181.530000
# Minute=163, Predicted=181.545017, Expected=181.765000
# Minute=164, Predicted=181.785676, Expected=181.840000
# Minute=165, Predicted=181.842313, Expected=181.761200
# Minute=166, Predicted=181.751173, Expected=181.750000
# Minute=167, Predicted=181.739716, Expected=181.630000
# Minute=168, Predicted=181.622326, Expected=181.610000
# Minute=169, Predicted=181.604613, Expected=181.560000
# Minute=170, Predicted=181.555890, Expected=181.454900
# Minute=171, Predicted=181.455389, Expected=181.400000
# Minute=172, Predicted=181.402528, Expected=181.530000
# Minute=173, Predicted=181.534281, Expected=181.570000
# Minute=174, Predicted=181.565183, Expected=181.660000
# Minute=175, Predicted=181.653132, Expected=181.550000
# Minute=176, Predicted=181.534070, Expected=181.660000
# Minute=177, Predicted=181.651549, Expected=181.560000
# Minute=178, Predicted=181.543933, Expected=181.623000
# Minute=179, Predicted=181.611560, Expected=181.690000
# Minute=180, Predicted=181.677303, Expected=181.600000
# Minute=181, Predicted=181.581886, Expected=181.500000
# Minute=182, Predicted=181.487892, Expected=181.570000
# Minute=183, Predicted=181.562122, Expected=181.360000
# Minute=184, Predicted=181.358921, Expected=181.221000
# Minute=185, Predicted=181.228632, Expected=181.351400
# Minute=186, Predicted=181.358850, Expected=181.130000
# Minute=187, Predicted=181.142616, Expected=181.080000
# Minute=188, Predicted=181.090530, Expected=181.180000
# Minute=189, Predicted=181.187862, Expected=181.230000
# Minute=190, Predicted=181.229953, Expected=181.330000
# Minute=191, Predicted=181.326952, Expected=181.340000
# Minute=192, Predicted=181.326165, Expected=181.280000
# Minute=193, Predicted=181.262542, Expected=181.350000
# Minute=194, Predicted=181.336925, Expected=181.240000
# Minute=195, Predicted=181.223728, Expected=181.250000
# Minute=196, Predicted=181.237603, Expected=181.190000
# Minute=197, Predicted=181.178597, Expected=181.380000
# Minute=198, Predicted=181.381799, Expected=181.270000
# Minute=199, Predicted=181.255749, Expected=181.290000
# Minute=200, Predicted=181.278349, Expected=181.190000
# Minute=201, Predicted=181.178730, Expected=181.250000
# Minute=202, Predicted=181.242032, Expected=181.180000
# Minute=203, Predicted=181.169572, Expected=181.260000
# Minute=204, Predicted=181.252839, Expected=181.310000
# Minute=205, Predicted=181.298779, Expected=181.530000
# Minute=206, Predicted=181.535038, Expected=181.530000
# Minute=207, Predicted=181.508948, Expected=181.464800
# Minute=208, Predicted=181.438848, Expected=181.240000
# Minute=209, Predicted=181.226620, Expected=181.260000
# Minute=210, Predicted=181.251136, Expected=181.170000
# Minute=211, Predicted=181.164940, Expected=181.120100
# Minute=212, Predicted=181.118029, Expected=181.089900
# Minute=213, Predicted=181.088833, Expected=181.300000
# Minute=214, Predicted=181.309992, Expected=181.050000
# Minute=215, Predicted=181.051058, Expected=180.814900
# Minute=216, Predicted=180.832374, Expected=180.830000
# Minute=217, Predicted=180.841167, Expected=180.880000
# Minute=218, Predicted=180.887193, Expected=180.999900
# Minute=219, Predicted=181.004612, Expected=180.920000
# Minute=220, Predicted=180.913218, Expected=180.840000
# Minute=221, Predicted=180.834589, Expected=180.810000
# Minute=222, Predicted=180.805563, Expected=180.704800
# Minute=223, Predicted=180.704148, Expected=180.570300
# Minute=224, Predicted=180.577305, Expected=180.594000
# Minute=225, Predicted=180.598895, Expected=180.551600
# Minute=226, Predicted=180.554733, Expected=180.690000
# Minute=227, Predicted=180.694846, Expected=180.520000
# Minute=228, Predicted=180.519141, Expected=180.515000
# Minute=229, Predicted=180.513901, Expected=180.800000
# Minute=230, Predicted=180.820976, Expected=180.920000
# Minute=231, Predicted=180.919911, Expected=180.930000
# Minute=232, Predicted=180.911506, Expected=181.010000
# Minute=233, Predicted=180.992333, Expected=180.920000
# Minute=234, Predicted=180.891572, Expected=180.725000
# Minute=235, Predicted=180.708739, Expected=180.490000
# Minute=236, Predicted=180.495524, Expected=180.484800
# Minute=237, Predicted=180.489239, Expected=180.550000
# Minute=238, Predicted=180.554039, Expected=180.580000
# Minute=239, Predicted=180.579178, Expected=180.470000
# Minute=240, Predicted=180.467714, Expected=180.570000
# Minute=241, Predicted=180.569482, Expected=180.540000
# Minute=242, Predicted=180.531724, Expected=180.500000
# Minute=243, Predicted=180.490820, Expected=180.510000
# Minute=244, Predicted=180.500970, Expected=180.214800
# Minute=245, Predicted=180.223740, Expected=180.160000
# Minute=246, Predicted=180.167793, Expected=180.170000
# Minute=247, Predicted=180.176273, Expected=180.290000
# Minute=248, Predicted=180.295568, Expected=180.274200
# Minute=249, Predicted=180.269185, Expected=180.150000
# Minute=250, Predicted=180.145738, Expected=180.190000
# Minute=251, Predicted=180.186282, Expected=180.290000
# Minute=252, Predicted=180.286219, Expected=180.150000
# Minute=253, Predicted=180.140553, Expected=180.150000
# Minute=254, Predicted=180.142625, Expected=179.920000
# Minute=255, Predicted=179.925808, Expected=179.880000
# Minute=256, Predicted=179.885605, Expected=180.000000
# Minute=257, Predicted=180.005890, Expected=179.870000
# Minute=258, Predicted=179.871831, Expected=179.845000
# Minute=259, Predicted=179.846142, Expected=179.760000
# Minute=260, Predicted=179.762412, Expected=179.890000
# Minute=261, Predicted=179.894017, Expected=179.827700
# Minute=262, Predicted=179.822270, Expected=180.059800
# Minute=263, Predicted=180.070831, Expected=179.970000
# Minute=264, Predicted=179.955609, Expected=179.850000
# Minute=265, Predicted=179.839095, Expected=179.825000
# Minute=266, Predicted=179.817033, Expected=179.750400
# Minute=267, Predicted=179.745151, Expected=179.840000
# Minute=268, Predicted=179.837088, Expected=179.910000
# Minute=269, Predicted=179.903179, Expected=179.675000
# Minute=270, Predicted=179.671274, Expected=179.530000
# Minute=271, Predicted=179.535738, Expected=179.410000
# Minute=272, Predicted=179.422217, Expected=179.260000
# Minute=273, Predicted=179.280477, Expected=179.276200
# Minute=274, Predicted=179.290927, Expected=179.490000
# Minute=275, Predicted=179.509192, Expected=179.570100
# Minute=276, Predicted=179.572419, Expected=179.640000
# Minute=277, Predicted=179.633136, Expected=179.560000
# Minute=278, Predicted=179.542217, Expected=179.620000
# Minute=279, Predicted=179.606289, Expected=179.710100
# Minute=280, Predicted=179.696809, Expected=179.510000
# Minute=281, Predicted=179.493025, Expected=179.670000
# Minute=282, Predicted=179.665918, Expected=179.800000
# Minute=283, Predicted=179.793582, Expected=179.950000
# Minute=284, Predicted=179.943644, Expected=180.030000
# Minute=285, Predicted=180.011397, Expected=180.150000
# Minute=286, Predicted=180.132643, Expected=180.130000
# Minute=287, Predicted=180.095723, Expected=179.900000
# Minute=288, Predicted=179.870296, Expected=179.900000
# Minute=289, Predicted=179.880541, Expected=179.850000
# Minute=290, Predicted=179.834946, Expected=179.930000
# Test RMSE: 0.120

# %%
yhat = forecast_lstm(lstm_model, 1, X)

# %%
yhat = y

# %%
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from math import sqrt
from matplotlib import pyplot
import numpy

# date-time parsing function for loading the dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
	df = DataFrame(data)
	columns = [df.shift(i) for i in range(1, lag+1)]
	columns.append(df)
	df = concat(columns, axis=1)
	df.fillna(0, inplace=True)
	return df

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# scale train and test data to [-1, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled

# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
	new_row = [x for x in X] + [value]
	array = numpy.array(new_row)
	array = array.reshape(1, len(array))
	inverted = scaler.inverse_transform(array)
	return inverted[0, -1]

# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
	X, y = train[:, 0:-1], train[:, -1]
	X = X.reshape(X.shape[0], 1, X.shape[1])
	model = Sequential()
	model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
	model.add(Dense(1))
	model.compile(loss='mean_squared_error', optimizer='adam')
	for i in range(nb_epoch):
		model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
		model.reset_states()
	return model

# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# load dataset
series = df['Close']

# transform data to be stationary
raw_values = series.values
diff_values = difference(raw_values, 1)

# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

# split data into train and test-sets
train, test = supervised_values[0:-40], supervised_values[-40:]

# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# repeat experiment
repeats = 3
error_scores = list()
for r in range(repeats):
	# fit the model
	lstm_model = fit_lstm(train_scaled, 1, 200, 4)
	# forecast the entire training dataset to build up state for forecasting
	train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
	lstm_model.predict(train_reshaped, batch_size=1)
	# walk-forward validation on the test data
	predictions = list()
	for i in range(len(test_scaled)):
		# make one-step forecast
		X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
		yhat = forecast_lstm(lstm_model, 1, X)
		# invert scaling
		yhat = invert_scale(scaler, X, yhat)
		# invert differencing
		yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
		# store forecast
		predictions.append(yhat)
	# report performance
	rmse = sqrt(mean_squared_error(raw_values[-40:], predictions))
	print('%d) Test RMSE: %.3f' % (r+1, rmse))
	error_scores.append(rmse)

# summarize results
results = DataFrame()
results['rmse'] = error_scores
print(results.describe())
results.boxplot()
pyplot.show()
# Out:
# Epoch 1/1
#  - 3s - loss: 0.1074
# Epoch 1/1
#  - 1s - loss: 0.1010
# Epoch 1/1
#  - 1s - loss: 0.1007
# Epoch 1/1
#  - 1s - loss: 0.1006
# Epoch 1/1
#  - 1s - loss: 0.1004
# Epoch 1/1
#  - 1s - loss: 0.1003
# Epoch 1/1
#  - 1s - loss: 0.1002
# Epoch 1/1
#  - 1s - loss: 0.1001
# Epoch 1/1
#  - 1s - loss: 0.1000
# Epoch 1/1
#  - 1s - loss: 0.0999
# Epoch 1/1
#  - 1s - loss: 0.0998
# Epoch 1/1
#  - 1s - loss: 0.0998
# Epoch 1/1
#  - 1s - loss: 0.0997
# Epoch 1/1
#  - 1s - loss: 0.0996
# Epoch 1/1
#  - 1s - loss: 0.0996
# Epoch 1/1
#  - 1s - loss: 0.0995
# Epoch 1/1
#  - 1s - loss: 0.0994
# Epoch 1/1
#  - 1s - loss: 0.0994
# Epoch 1/1
#  - 1s - loss: 0.0993
# Epoch 1/1
#  - 1s - loss: 0.0992
# Epoch 1/1
#  - 1s - loss: 0.0992
# Epoch 1/1
#  - 1s - loss: 0.0991
# Epoch 1/1
#  - 1s - loss: 0.0991
# Epoch 1/1
#  - 1s - loss: 0.0990
# Epoch 1/1
#  - 1s - loss: 0.0990
# Epoch 1/1
#  - 1s - loss: 0.0989
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# 1) Test RMSE: 0.123
# Epoch 1/1
#  - 3s - loss: 0.1093
# Epoch 1/1
#  - 1s - loss: 0.1008
# Epoch 1/1
#  - 1s - loss: 0.1007
# Epoch 1/1
#  - 1s - loss: 0.1005
# Epoch 1/1
#  - 1s - loss: 0.1003
# Epoch 1/1
#  - 1s - loss: 0.1002
# Epoch 1/1
#  - 1s - loss: 0.1000
# Epoch 1/1
#  - 1s - loss: 0.0998
# Epoch 1/1
#  - 1s - loss: 0.0997
# Epoch 1/1
#  - 1s - loss: 0.0996
# Epoch 1/1
#  - 1s - loss: 0.0994
# Epoch 1/1
#  - 1s - loss: 0.0993
# Epoch 1/1
#  - 1s - loss: 0.0992
# Epoch 1/1
#  - 1s - loss: 0.0991
# Epoch 1/1
#  - 1s - loss: 0.0989
# Epoch 1/1
#  - 1s - loss: 0.0989
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0978
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0977
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0976
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0975
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0974
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# Epoch 1/1
#  - 1s - loss: 0.0973
# 2) Test RMSE: 0.123
# Epoch 1/1
#  - 3s - loss: 0.1055
# Epoch 1/1
#  - 1s - loss: 0.1026
# Epoch 1/1
#  - 1s - loss: 0.1020
# Epoch 1/1
#  - 1s - loss: 0.1016
# Epoch 1/1
#  - 1s - loss: 0.1012
# Epoch 1/1
#  - 1s - loss: 0.1009
# Epoch 1/1
#  - 1s - loss: 0.1007
# Epoch 1/1
#  - 1s - loss: 0.1004
# Epoch 1/1
#  - 1s - loss: 0.1003
# Epoch 1/1
#  - 1s - loss: 0.1001
# Epoch 1/1
#  - 1s - loss: 0.0999
# Epoch 1/1
#  - 1s - loss: 0.0998
# Epoch 1/1
#  - 1s - loss: 0.0997
# Epoch 1/1
#  - 1s - loss: 0.0996
# Epoch 1/1
#  - 1s - loss: 0.0995
# Epoch 1/1
#  - 1s - loss: 0.0994
# Epoch 1/1
#  - 1s - loss: 0.0993
# Epoch 1/1
#  - 1s - loss: 0.0993
# Epoch 1/1
#  - 1s - loss: 0.0992
# Epoch 1/1
#  - 1s - loss: 0.0991
# Epoch 1/1
#  - 1s - loss: 0.0991
# Epoch 1/1
#  - 1s - loss: 0.0990
# Epoch 1/1
#  - 1s - loss: 0.0990
# Epoch 1/1
#  - 1s - loss: 0.0989
# Epoch 1/1
#  - 1s - loss: 0.0989
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0988
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0987
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0986
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0985
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0984
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0983
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0982
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0981
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0980
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# Epoch 1/1
#  - 1s - loss: 0.0979
# 3) Test RMSE: 0.122
#            rmse
# count  3.000000
# mean   0.122517
# std    0.000440
# min    0.122011
# 25%    0.122372
# 50%    0.122732
# 75%    0.122770
# max    0.122808

# %% [markdown]
# Normalizing
